# %% [markdown]
# # Uvod #
#
# U ovoj vježbi izgradit ćete model za predviđanje otkazivanja hotela s binarnim klasifikatorom.

# %%
# Setup plotting
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-whitegrid')
# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('animation', html='html5')

# %% [markdown]
# Prvo učitajte skup podataka *Hotel cancellations*.

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer

hotel = pd.read_csv('./input/hotel.csv')

X = hotel.copy()
y = X.pop('is_canceled')

X['arrival_date_month'] = \
    X['arrival_date_month'].map(
        {'January':1, 'February': 2, 'March':3,
         'April':4, 'May':5, 'June':6, 'July':7,
         'August':8, 'September':9, 'October':10,
         'November':11, 'December':12}
    )

features_num = [
    "lead_time", "arrival_date_week_number",
    "arrival_date_day_of_month", "stays_in_weekend_nights",
    "stays_in_week_nights", "adults", "children", "babies",
    "is_repeated_guest", "previous_cancellations",
    "previous_bookings_not_canceled", "required_car_parking_spaces",
    "total_of_special_requests", "adr",
]
features_cat = [
    "hotel", "arrival_date_month", "meal",
    "market_segment", "distribution_channel",
    "reserved_room_type", "deposit_type", "customer_type",
]

transformer_num = make_pipeline(
    SimpleImputer(strategy="constant"), # there are a few missing values
    StandardScaler(),
)
transformer_cat = make_pipeline(
    SimpleImputer(strategy="constant", fill_value="NA"),
    OneHotEncoder(handle_unknown='ignore'),
)

preprocessor = make_column_transformer(
    (transformer_num, features_num),
    (transformer_cat, features_cat),
)

# stratify - make sure classes are evenlly represented across splits
X_train, X_valid, y_train, y_valid = \
    train_test_split(X, y, stratify=y, train_size=0.75)

X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)

input_shape = [X_train.shape[1]]

# %% [markdown]
# # 1) Definirajte model #
#
# Model koji ćemo ovaj put koristiti imat će i batch normalization i dropout layer. Radi lakšeg čitanja razbili smo dijagram u blokove, ali možete ga definirati sloj po sloj kao i obično.
#
# Definirajte model s arhitekturom danom ovim dijagramom:
#
# <figure style="padding: 1em;">
# <img src="figs/V04o59Z.png" width="400" alt="Diagram of network architecture: BatchNorm, Dense, BatchNorm, Dropout, Dense, BatchNorm, Dropout, Dense.">
# <figcaption style="textalign: center; font-style: italic"><center>Dijagram binarnog klasifikatora.</center></figcaption>
# </figure>

# %%
from tensorflow import keras
from tensorflow.keras import layers

# YOUR CODE HERE: define the model given in the diagram
model =  keras.Sequential([
    layers.BatchNormalization(input_shape=input_shape),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(1, activation='sigmoid'),
])
# Out:
# c:\Users\PC\PSU\psu\Lib\site-packages\keras\src\layers\normalization\batch_normalization.py:143: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# # 2) Dodajte optimizator, loss i metriku #
#
# Sada sastavite model s Adamovim optimizatorom i binarnim verzijama cross-entropy loss-a i metrike accuracy-a.

# %%
# YOUR CODE HERE
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['binary_accuracy'],
)

# %% [markdown]
# Na kraju, pokrenite ovu ćeliju da uvježbate model i pogledate krivulje učenja. Može trajati oko 60 do 70 epoha, što može potrajati minutu ili dvije.

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=5,
    min_delta=0.001,
    restore_best_weights=True,
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=200,
    callbacks=[early_stopping],
)

history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot(title="Cross-entropy")
history_df.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot(title="Accuracy")
# Out:
# Epoch 1/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - binary_accuracy: 0.7404 - loss: 0.5436 - val_binary_accuracy: 0.8009 - val_loss: 0.4365
# Epoch 2/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - binary_accuracy: 0.7972 - loss: 0.4282 - val_binary_accuracy: 0.8143 - val_loss: 0.4030
# Epoch 3/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - binary_accuracy: 0.8047 - loss: 0.4143 - val_binary_accuracy: 0.8174 - val_loss: 0.3965
# Epoch 4/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - binary_accuracy: 0.8118 - loss: 0.4037 - val_binary_accuracy: 0.8195 - val_loss: 0.3920
# Epoch 5/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - binary_accuracy: 0.8106 - loss: 0.4006 - val_binary_accuracy: 0.8180 - val_loss: 0.3893
# Epoch 6/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - binary_accuracy: 0.8162 - loss: 0.3933 - val_binary_accuracy: 0.8224 - val_loss: 0.3876
# Epoch 7/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - binary_accuracy: 0.8181 - loss: 0.3873 - val_binary_accuracy: 0.8251 - val_loss: 0.3829
# Epoch 8/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - binary_accuracy: 0.8198 - loss: 0.3861 - val_binary_accuracy: 0.8264 - val_loss: 0.3835
# Epoch 9/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - binary_accuracy: 0.8252 - loss: 0.3801 - val_binary_accuracy: 0.8275 - val_loss: 0.3785
# Epoch 10/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - binary_accuracy: 0.8237 - loss: 0.3811 - val_binary_accuracy: 0.8278 - val_loss: 0.3751
# Epoch 11/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - binary_accuracy: 0.8240 - loss: 0.3778 - val_binary_accuracy: 0.8294 - val_loss: 0.3767
# Epoch 12/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - binary_accuracy: 0.8258 - loss: 0.3732 - val_binary_accuracy: 0.8281 - val_loss: 0.3772
# Epoch 13/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - binary_accuracy: 0.8303 - loss: 0.3706 - val_binary_accuracy: 0.8289 - val_loss: 0.3755
# Epoch 14/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - binary_accuracy: 0.8287 - loss: 0.3694 - val_binary_accuracy: 0.8306 - val_loss: 0.3696
# Epoch 15/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - binary_accuracy: 0.8296 - loss: 0.3674 - val_binary_accuracy: 0.8331 - val_loss: 0.3660
# Epoch 16/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - binary_accuracy: 0.8290 - loss: 0.3670 - val_binary_accuracy: 0.8342 - val_loss: 0.3652
# Epoch 17/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - binary_accuracy: 0.8312 - loss: 0.3630 - val_binary_accuracy: 0.8344 - val_loss: 0.3657
# Epoch 18/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - binary_accuracy: 0.8325 - loss: 0.3623 - val_binary_accuracy: 0.8348 - val_loss: 0.3656
# Epoch 19/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - binary_accuracy: 0.8341 - loss: 0.3590 - val_binary_accuracy: 0.8349 - val_loss: 0.3658
# Epoch 20/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - binary_accuracy: 0.8356 - loss: 0.3581 - val_binary_accuracy: 0.8349 - val_loss: 0.3612
# Epoch 21/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - binary_accuracy: 0.8357 - loss: 0.3553 - val_binary_accuracy: 0.8373 - val_loss: 0.3607
# Epoch 22/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - binary_accuracy: 0.8349 - loss: 0.3575 - val_binary_accuracy: 0.8377 - val_loss: 0.3580
# Epoch 23/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - binary_accuracy: 0.8378 - loss: 0.3544 - val_binary_accuracy: 0.8359 - val_loss: 0.3588
# Epoch 24/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - binary_accuracy: 0.8363 - loss: 0.3544 - val_binary_accuracy: 0.8361 - val_loss: 0.3598
# Epoch 25/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - binary_accuracy: 0.8375 - loss: 0.3515 - val_binary_accuracy: 0.8378 - val_loss: 0.3572
# Epoch 26/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - binary_accuracy: 0.8385 - loss: 0.3513 - val_binary_accuracy: 0.8350 - val_loss: 0.3626
# Epoch 27/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - binary_accuracy: 0.8410 - loss: 0.3452 - val_binary_accuracy: 0.8385 - val_loss: 0.3558
# Epoch 28/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - binary_accuracy: 0.8419 - loss: 0.3430 - val_binary_accuracy: 0.8377 - val_loss: 0.3592
# Epoch 29/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - binary_accuracy: 0.8403 - loss: 0.3457 - val_binary_accuracy: 0.8366 - val_loss: 0.3560
# Epoch 30/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - binary_accuracy: 0.8407 - loss: 0.3461 - val_binary_accuracy: 0.8374 - val_loss: 0.3593
# Epoch 31/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - binary_accuracy: 0.8419 - loss: 0.3444 - val_binary_accuracy: 0.8369 - val_loss: 0.3573
# Epoch 32/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - binary_accuracy: 0.8404 - loss: 0.3447 - val_binary_accuracy: 0.8396 - val_loss: 0.3525
# Epoch 33/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - binary_accuracy: 0.8422 - loss: 0.3420 - val_binary_accuracy: 0.8411 - val_loss: 0.3544
# Epoch 34/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - binary_accuracy: 0.8433 - loss: 0.3397 - val_binary_accuracy: 0.8401 - val_loss: 0.3546
# Epoch 35/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - binary_accuracy: 0.8451 - loss: 0.3383 - val_binary_accuracy: 0.8390 - val_loss: 0.3519
# Epoch 36/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - binary_accuracy: 0.8444 - loss: 0.3397 - val_binary_accuracy: 0.8375 - val_loss: 0.3517
# Epoch 37/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - binary_accuracy: 0.8433 - loss: 0.3407 - val_binary_accuracy: 0.8416 - val_loss: 0.3519
# <Axes: title={'center': 'Accuracy'}>

# %% [markdown]
# # 3) Train and verify #
#
#
# Što mislite o krivuljama učenja? Izgleda li kao model underfit ili overfit? Je li cross-entropy loss bio dobra zamjena za accuracy?

# %% [markdown]
# # Izgleda dobro
