# %% [markdown]
# ## Exercise: Analyzing and Visualizing Data with Matplotlib, Pandas, and NumPy
#
# The Boston Housing Dataset is a derived from information collected by the U.S. Census Service concerning housing in the area of Boston MA. The following describes the dataset columns:
#
# - CRIM - per capita crime rate by town
# - ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
# - INDUS - proportion of non-retail business acres per town.
# - CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
# - NOX - nitric oxides concentration (parts per 10 million)
# - RM - average number of rooms per dwelling
# - AGE - proportion of owner-occupied units built prior to 1940
# - DIS - weighted distances to five Boston employment centres
# - RAD - index of accessibility to radial highways
# - TAX - full-value property-tax rate per $10,000
# - PTRATIO - pupil-teacher ratio by town
# - B - 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
# - LSTAT - % lower status of the population
# - MEDV - Median value of owner-occupied homes in $1000's
#
# ### Part 1: Data Preparation
#
# In this part of the exercise, you will use Pandas and NumPy to load and preprocess data. For this exercise, we will use a dataset of housing prices in Boston.
#
# 1.  Download the Boston Housing dataset from [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data) and save it to your local computer.
# 2.  Load the dataset into a Pandas DataFrame and examine its contents. The dataset should have 506 rows and 14 columns.
# 3.  Use NumPy to calculate some basic statistics about the dataset, such as the mean, median, standard deviation, minimum, and maximum values of each column.
# 4.  Clean the dataset by removing any missing or invalid values. You can use Pandas' `dropna()` method for this.

# %%
import pandas as pd

# URL of the dataset
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data"

# Column names for the dataset
column_names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']

# Load the dataset into a Pandas DataFrame
housing_data = pd.read_csv(url, header=None, delim_whitespace=True, names=column_names)

# Display the first few rows of the dataset
print("First few rows of the dataset:")
print(housing_data.head())
# Out:
# C:\Users\belam\AppData\Local\Temp\ipykernel_25544\3322736034.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   housing_data = pd.read_csv(url, header=None, delim_whitespace=True, names=column_names)
# First few rows of the dataset:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
import numpy as np

# Calculate mean, median, standard deviation, minimum, and maximum values for each column
mean_values = np.mean(housing_data, axis=0)
median_values = np.median(housing_data, axis=0)
std_values = np.std(housing_data, axis=0)
min_values = np.min(housing_data, axis=0)
max_values = np.max(housing_data, axis=0)

# Display the calculated statistics
print("Mean values:")
print(mean_values)
print("\nMedian values:")
print(median_values)
print("\nStandard deviation values:")
print(std_values)
print("\nMinimum values:")
print(min_values)
print("\nMaximum values:")
print(max_values)
# Out:
# Mean values:
# CRIM         3.613524
# ZN          11.363636
# INDUS       11.136779
# CHAS         0.069170
# NOX          0.554695
# RM           6.284634
# AGE         68.574901
# DIS          3.795043
# RAD          9.549407
# TAX        408.237154
# PTRATIO     18.455534
# B          356.674032
# LSTAT       12.653063
# MEDV        22.532806
# dtype: float64
#
# Median values:
# [2.56510e-01 0.00000e+00 9.69000e+00 0.00000e+00 5.38000e-01 6.20850e+00
#  7.75000e+01 3.20745e+00 5.00000e+00 3.30000e+02 1.90500e+01 3.91440e+02
#  1.13600e+01 2.12000e+01]
#
# Standard deviation values:
# CRIM         8.593041
# ZN          23.299396
# INDUS        6.853571
# CHAS         0.253743
# NOX          0.115763
# RM           0.701923
# AGE         28.121033
# DIS          2.103628
# RAD          8.698651
# TAX        168.370495
# PTRATIO      2.162805
# B           91.204607
# LSTAT        7.134002
# MEDV         9.188012
# dtype: float64
#
# Minimum values:
# CRIM         0.00632
# ZN           0.00000
# INDUS        0.46000
# CHAS         0.00000
# NOX          0.38500
# RM           3.56100
# AGE          2.90000
# DIS          1.12960
# RAD          1.00000
# TAX        187.00000
# PTRATIO     12.60000
# B            0.32000
# LSTAT        1.73000
# MEDV         5.00000
# dtype: float64
#
# Maximum values:
# CRIM        88.9762
# ZN         100.0000
# INDUS       27.7400
# CHAS         1.0000
# NOX          0.8710
# RM           8.7800
# AGE        100.0000
# DIS         12.1265
# RAD         24.0000
# TAX        711.0000
# PTRATIO     22.0000
# B          396.9000
# LSTAT       37.9700
# MEDV        50.0000
# dtype: float64

# %%
# Clean the dataset by removing any missing or invalid values
cleaned_housing_data = housing_data.dropna()

# Check if there are any missing values after cleaning
print("Missing values after cleaning:")
print(cleaned_housing_data.isnull().sum())
# Out:
# Missing values after cleaning:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %% [markdown]
# ### Part 2: Data Visualization
#
# In this part of the exercise, you will use Matplotlib to create some visualizations of the housing data.
#
# 1.  Create a scatter plot of the housing prices (`MEDV`) versus the number of rooms (`RM`). Label the axes and add a title to the plot.
# 2.  Create a histogram of the housing prices (`MEDV`). Label the axes and add a title to the plot.
# 3.  Create a box plot of the housing prices (`MEDV`) grouped by the proximity to employment centers (`DIS`). Label the axes and add a title to the plot.

# %%
import matplotlib.pyplot as plt

# Create the scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(housing_data['RM'], housing_data['MEDV'], alpha=0.5)  # Alpha controls the transparency of points
plt.title('Housing Prices vs Number of Rooms')
plt.xlabel('Number of Rooms (RM)')
plt.ylabel('Housing Prices (MEDV)')
plt.grid(True)  # Add grid lines for better readability
plt.show()

# %%
import matplotlib.pyplot as plt

# Create the histogram
plt.figure(figsize=(8, 6))
plt.hist(housing_data['MEDV'], bins=30, edgecolor='black')  # bins=30 sets the number of bins and edgecolor='black' sets the color of the bin edges
plt.title('Distribution of Housing Prices')
plt.xlabel('Housing Prices (MEDV)')
plt.ylabel('Frequency')
plt.grid(True)  # Add grid lines for better readability
plt.show()

# %%
import matplotlib.pyplot as plt

# Create the box plot
plt.figure(figsize=(8, 6))
housing_data.boxplot(column='MEDV', by='DIS')
plt.title('Housing Prices by Proximity to Employment Centers')
plt.xlabel('Proximity to Employment Centers (DIS)')
plt.ylabel('Housing Prices (MEDV)')
plt.grid(True)  # Add grid lines for better readability
plt.show()

# %% [markdown]
# ### Part 3: Data Analysis
#
# In this part of the exercise, you will use Pandas and NumPy to perform some basic data analysis on the housing data.
#
# 1.  Calculate the correlation coefficient between the housing prices (`MEDV`) and the number of rooms (`RM`) using NumPy's `corrcoef()` method.
# 2.  Calculate the mean housing price (`MEDV`) for each neighborhood (`CHAS`). You can use Pandas' `groupby()` method for this.
# 3.  Calculate the percentage of houses that have more than 7 rooms (`RM`). You can use Pandas' `value_counts()` method for this.

# %%
import numpy as np

# Calculate correlation coefficient between MEDV and RM
correlation_coefficient = np.corrcoef(housing_data['MEDV'], housing_data['RM'])[0, 1]
print("Correlation Coefficient between MEDV and RM:", correlation_coefficient)
# Out:
# Correlation Coefficient between MEDV and RM: 0.6953599470715396

# %%
# Calculate mean housing price for each neighborhood
mean_price_by_neighborhood = housing_data.groupby('CHAS')['MEDV'].mean()
print("Mean Housing Price by Neighborhood (CHAS):")
print(mean_price_by_neighborhood)
# Out:
# Mean Housing Price by Neighborhood (CHAS):
# CHAS
# 0    22.093843
# 1    28.440000
# Name: MEDV, dtype: float64

# %%
# Calculate percentage of houses with more than 7 rooms
percentage_more_than_7_rooms = (housing_data['RM'] > 7).mean() * 100
print("Percentage of Houses with More than 7 Rooms:", percentage_more_than_7_rooms, "%")
# Out:
# Percentage of Houses with More than 7 Rooms: 12.648221343873518 %

# %% [markdown]
# ### Part 4: Putting it all together
#
# In this final part of the exercise, you will use all three libraries to create a complete data analysis and visualization pipeline.
#
# 1.  Load the dataset and preprocess it as before.
# 2.  Create the scatter plot and histogram as before.
# 3.  Calculate the correlation coefficient between the housing prices and the number of rooms as before.
# 4.  Group the data by the proximity to employment centers and calculate the mean housing prices as before.
# 5.  Create a bar chart of the mean housing prices by proximity to employment centers. Label the axes and add a title to the plot.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
column_names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'PRICE']
df = pd.read_csv('housing.data', header=None, delim_whitespace=True, names=column_names)

# Preprocess the data
# Drop rows with missing values
df.dropna(inplace=True)

# Create scatter plot
plt.figure(figsize=(10, 5))
plt.scatter(df['RM'], df['PRICE'], alpha=0.5)
plt.title('Scatter Plot of Number of Rooms vs Housing Prices')
plt.xlabel('Number of Rooms')
plt.ylabel('Housing Prices')
plt.grid(True)
plt.show()

# Create histogram
plt.figure(figsize=(10, 5))
plt.hist(df['PRICE'], bins=20, edgecolor='black')
plt.title('Histogram of Housing Prices')
plt.xlabel('Housing Prices')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# Calculate correlation coefficient
correlation_coefficient = np.corrcoef(df['RM'], df['PRICE'])[0, 1]
print("Correlation Coefficient between Number of Rooms and Housing Prices:", correlation_coefficient)

# Group data by proximity to employment centers and calculate mean housing prices
mean_prices_by_proximity = df.groupby('RAD')['PRICE'].mean()

# Create bar chart
plt.figure(figsize=(10, 5))
mean_prices_by_proximity.plot(kind='bar', color='skyblue')
plt.title('Mean Housing Prices by Proximity to Employment Centers')
plt.xlabel('Proximity to Employment Centers')
plt.ylabel('Mean Housing Prices')
plt.xticks(rotation=0)
plt.grid(axis='y')
plt.show()
# Out:
# C:\Users\belam\AppData\Local\Temp\ipykernel_25544\43236846.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv('housing.data', header=None, delim_whitespace=True, names=column_names)
# Correlation Coefficient between Number of Rooms and Housing Prices: 0.6953599470715395
